# %% [markdown]
# #### KDD
# ##### Aditya Ambre
# ##### 20200802023
# ##### LAB - 3 Preprocessing Normalization and Standardization

# %% [markdown]
# **Aim:** To perform Preprocessing Normalization and Standardization on the given dataset using
#
# 1.	By creating functions.
# 2.	By using the sklearn library.
#
# And validating the results.

# %%
# Importing Required libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
# Loading dataset
house_df = pd.read_csv("train.csv")
house_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
house_df = house_df.set_index(["Id"])
house_df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
all_data_na = (house_df.isnull().sum() / len(house_df)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending = True)
missing_data = pd.DataFrame({'Missing Ratio (in %)':all_data_na})
missing_data.head(20)
# Out:
# Empty DataFrame
# Columns: [Missing Ratio (in %)]
# Index: []

# %%
house_df = house_df.drop(['PoolQC', 'MiscFeature','Alley','Fence','FireplaceQu'], axis=1)
house_df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 1             60       RL         65.0     8450   Pave      Reg         Lvl
# 2             20       RL         80.0     9600   Pave      Reg         Lvl
# 3             60       RL         68.0    11250   Pave      IR1         Lvl
# 4             70       RL         60.0     9550   Pave      IR1         Lvl
# 5             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1456          60       RL         62.0     7917   Pave      Reg         Lvl
# 1457          20       RL         85.0    13175   Pave      Reg         Lvl
# 1458          70       RL         66.0     9042   Pave      Reg         Lvl
# 1459          20       RL         68.0     9717   Pave      Reg         Lvl
# 1460          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %%
a = house_df.isnull().sum().sort_values(ascending=False)[:19].to_frame()
l = list(a.index.values)
house_df[l].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotFrontage   1201 non-null   float64
#  1   GarageType    1379 non-null   object
#  2   GarageYrBlt   1379 non-null   float64
#  3   GarageFinish  1379 non-null   object
#  4   GarageQual    1379 non-null   object
#  5   GarageCond    1379 non-null   object
#  6   BsmtFinType2  1422 non-null   object
#  7   BsmtExposure  1422 non-null   object
#  8   BsmtQual      1423 non-null   object
#  9   BsmtCond      1423 non-null   object
#  10  BsmtFinType1  1423 non-null   object
#  11  MasVnrArea    1452 non-null   float64
#  12  MasVnrType    1452 non-null   object
#  13  Electrical    1459 non-null   object
#  14  KitchenAbvGr  1460 non-null   int64
#  15  BedroomAbvGr  1460 non-null   int64
#  16  HalfBath      1460 non-null   int64
#  17  FullBath      1460 non-null   int64
# ...

# %%
num_columns = list(house_df[l].select_dtypes(include=np.number).columns)
cat_columns = list(house_df[l].select_dtypes(exclude=np.number).columns)

# %%
print("Variables : ", num_columns)
print("Categorical Variables : ",cat_columns)
# Out:
# Variables :  ['LotFrontage', 'GarageYrBlt', 'MasVnrArea', 'KitchenAbvGr', 'BedroomAbvGr', 'HalfBath', 'FullBath', 'BsmtHalfBath']
# Categorical Variables :  ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'BsmtFinType2', 'BsmtExposure', 'BsmtQual', 'BsmtCond', 'BsmtFinType1', 'MasVnrType', 'Electrical']

# %%
for i in list(house_df[l].columns):
  if i in num_columns:
    house_df[i].fillna(house_df[i].median(), inplace=True)
  else:
    house_df[i].fillna(house_df[i].mode()[0], inplace=True)

# %%
from numpy.core.multiarray import asanyarray
all_data_na = (house_df.isnull().sum() / len(house_df)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending = True)
missing_data = pd.DataFrame({'Missing Ratio (in %)':all_data_na})
missing_data
# Out:
# Empty DataFrame
# Columns: [Missing Ratio (in %)]
# Index: []

# %%
house_df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 1             60       RL         65.0     8450   Pave      Reg         Lvl
# 2             20       RL         80.0     9600   Pave      Reg         Lvl
# 3             60       RL         68.0    11250   Pave      IR1         Lvl
# 4             70       RL         60.0     9550   Pave      IR1         Lvl
# 5             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1456          60       RL         62.0     7917   Pave      Reg         Lvl
# 1457          20       RL         85.0    13175   Pave      Reg         Lvl
# 1458          70       RL         66.0     9042   Pave      Reg         Lvl
# 1459          20       RL         68.0     9717   Pave      Reg         Lvl
# 1460          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %%
num_columns = list(house_df.select_dtypes(include=np.number).columns)
numeric_house_df = house_df[num_columns]
numeric_house_df
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1             60         65.0     8450            7            5       2003
# 2             20         80.0     9600            6            8       1976
# 3             60         68.0    11250            7            5       2001
# 4             70         60.0     9550            7            5       1915
# 5             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1456          60         62.0     7917            6            5       1999
# 1457          20         85.0    13175            6            6       1978
# 1458          70         66.0     9042            7            9       1941
# 1459          20         68.0     9717            5            6       1950
# 1460          20         75.0     9937            5            6       1965
#
# ...

# %%
#LOG SCALING

def log_scaling(df):
  new = df
  for i in list(new.columns):
    new[i] = np.log(df[i])
    return new

california_log_scaling = log_scaling(numeric_house_df)
california_log_scaling

# %%
# Min-Max
def min_max(df):
  new = df
  for i in list(new.columns):
    new[i] = (new[i] - min(new[i]))/(max(new[i]) - min(new[i]))
    return new

california_min_max_udf = min_max(numeric_house_df)
california_min_max_udf

# %%
# validating Min-Max
min_max_scaler = MinMaxScaler()
california_min_max_sklearn = pd.DataFrame()
l = list(numeric_house_df.columns)
california_min_max_sklearn[l] = min_max_scaler.fit_transform(numeric_house_df[l])

california_min_max_sklearn
# Out:
#       MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       0.487992     0.150685  0.033420     0.666667        0.500   0.949275
# 1       0.000000     0.202055  0.038795     0.555556        0.875   0.753623
# 2       0.487992     0.160959  0.046507     0.666667        0.500   0.934783
# 3       0.556464     0.133562  0.038561     0.666667        0.500   0.311594
# 4       0.487992     0.215753  0.060576     0.777778        0.500   0.927536
# ...          ...          ...       ...          ...          ...        ...
# 1455    0.487992     0.140411  0.030929     0.555556        0.500   0.920290
# 1456    0.000000     0.219178  0.055505     0.555556        0.625   0.768116
# 1457    0.556464     0.154110  0.036187     0.666667        1.000   0.500000
# 1458    0.000000     0.160959  0.039342     0.444444        0.625   0.565217
# 1459    0.000000     0.184932  0.040370     0.444444        0.625   0.673913
#
# ...

# %%
# Z-Score
def z_scores(df):
  new = df
  for i in list(new.columns):
    new[i] = (new[i] - np.mean(new[i]))/(np.std(new[i]))
    return new

california_z_score_udf = z_scores(numeric_house_df)
california_z_score_udf

# %%
# Validating z-score
z_score = StandardScaler()
california_z_scores_sklearn = pd.DataFrame()
l = list(numeric_house_df.columns)
california_z_scores_sklearn[l] = z_score.fit_transform(numeric_house_df[l])

california_z_scores_sklearn
# Out:
#       MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       0.430516    -0.220875 -0.207142     0.651479    -0.517200   1.050994
# 1      -1.128983     0.460320 -0.091886    -0.071836     2.179628   0.156734
# 2       0.430516    -0.084636  0.073480     0.651479    -0.517200   0.984752
# 3       0.649335    -0.447940 -0.096897     0.651479    -0.517200  -1.863632
# 4       0.430516     0.641972  0.375148     1.374795    -0.517200   0.951632
# ...          ...          ...       ...          ...          ...        ...
# 1455    0.430516    -0.357114 -0.260560    -0.071836    -0.517200   0.918511
# 1456   -1.128983     0.687385  0.266407    -0.071836     0.381743   0.222975
# 1457    0.649335    -0.175462 -0.147810     0.651479     3.078570  -1.002492
# 1458   -1.128983    -0.084636 -0.080160    -0.795151     0.381743  -0.704406
# 1459   -1.128983     0.233255 -0.058112    -0.795151     0.381743  -0.207594
#
# ...

# %% [markdown]
# # **Observation**

# %% [markdown]
# 1. Diemensions of the Data set have been greatly reduced to  <b>1460 X 37</b>
# 2. LotFrontage  has the least number of Non Null values <b>1201</b>
# 3. During Data Preprocessing we have reduce <b>38</b> non numerical Data Coloumns.

# %% [markdown]
# ##### Conclusion : Data preprocessing , Normalization and Standardization have been perfomed successfully on the Houseprices Dataset.
